# %% [markdown]
# <a href="https://colab.research.google.com/github/PvrpleJade/AIDA-2/blob/main/Quiz_1_Midterms_(Santos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1 Read the dataset in xls file.
# ## 2 Clean the data if not yet cleaned.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
poke = pd.read_excel("/content/drive/My Drive/class list aida 2/pokemon.xlsx")
poke
# Out:
#          #       Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0      001  Bulbasaur   GRASS    318   45      49       49              65
# 1      001  Bulbasaur  POISON    318   45      49       49              65
# 2      002    Ivysaur   GRASS    405   60      62       63              80
# 3      002    Ivysaur  POISON    405   60      62       63              80
# 4      003   Venusaur   GRASS    525   80      82       83             100
# ...    ...        ...     ...    ...  ...     ...      ...             ...
# 1163   716    Xerneas   FAIRY    680  126     131       95             131
# 1164   717    Yveltal    DARK    680  126     131       95             131
# 1165   717    Yveltal  FLYING    680  126     131       95             131
# 1166   718    Zygarde  DRAGON    600  108     100      121              81
# 1167   718    Zygarde  GROUND    600  108     100      121              81
#
#       Special Defense  Speed
# 0                  65     45
# ...

# %%
df2 = poke[poke.duplicated(keep=False)]
print(df2)
# Out:
#            #                       Name      Type  Total   HP  Attack  \
# 19     009.1             Mega Blastoise     WATER    630   79     103
# 20     009.1             Mega Blastoise     WATER    630   79     103
# 178    115.1            Mega Kangaskhan    NORMAL    590  105     125
# 179    115.1            Mega Kangaskhan    NORMAL    590  105     125
# 238    150.2              Mega Mewtwo Y   PSYCHIC    780  106     150
# 239    150.2              Mega Mewtwo Y   PSYCHIC    780  106     150
# 491    306.1                Mega Aggron     STEEL    630   70     140
# 492    306.1                Mega Aggron     STEEL    630   70     140
# 501    310.1             Mega Manectric  ELECTRIC    575   70      75
# 502    310.1             Mega Manectric  ELECTRIC    575   70      75
# 568    354.1               Mega Banette     GHOST    555   64     165
# 569    354.1               Mega Banette     GHOST    555   64     165
# ...

# %% [markdown]
# ## 3. Create a python program that will show the descriptive analysis of the datasets ( Count, min, max, standard deviation, 75%,50%and 25%)

# %%
poke.describe()
# Out:
#              Total           HP       Attack      Defense  Special Attack  \
# count  1168.000000  1168.000000  1168.000000  1168.000000     1168.000000
# mean    435.632705    69.525685    78.815925    74.369863       72.619007
# std     116.527166    24.919600    31.714658    30.761824       31.770755
# min     180.000000     1.000000     5.000000     5.000000       10.000000
# 25%     334.000000    50.000000    55.000000    50.000000       50.000000
# 50%     453.000000    66.000000    75.000000    70.000000       65.000000
# 75%     515.000000    82.000000   100.000000    90.000000       95.000000
# max     780.000000   255.000000   190.000000   230.000000      194.000000
#
#        Special Defense        Speed
# count      1168.000000  1168.000000
# mean         71.715753    68.586473
# std          27.265611    28.315690
# min          20.000000     5.000000
# 25%          50.000000    47.000000
# 50%          70.000000    65.500000
# 75%          90.000000    90.000000
# ...

# %% [markdown]
# ##4.Draw a scatter plot .

# %%
A = plt.scatter(poke['Attack'],poke['HP'],Color='Blue')
B = plt.scatter(poke['Defense'],poke['HP'],Color='Red')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
A = np.array (poke['Attack'])
B = np.array (poke['Defense'])
A = plt.scatter(poke['Attack'],poke['HP'],Color='Blue')
B = plt.scatter(poke['Defense'],poke['HP'],Color='Red')
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
