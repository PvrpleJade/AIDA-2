# %% [markdown]
# <a href="https://colab.research.google.com/github/PvrpleJade/AIDA-2/blob/main/Lab_4_(Santos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###SANTOS, Franz Nico
#
# ###201813672

# %% [markdown]
# ##1. Is the no. of facebook likes in Director's Facebook page matters to the gross sales of the movie?
#
# ####-Yes, the number of facebook likes on a page can greatly affect the gross sale of the movie.

# %% [markdown]
# ##2.What is the correlation , is it negative or positive correlation? Show your graph?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-093e63d1-ed97-4a62-95f7-3def82c55dce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-093e63d1-ed97-4a62-95f7-3def82c55dce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("movie_metadata_cleaned.csv",nrows=100)
data
# Out:
#     Unnamed: 0                                        movie_title  color  \
# 0            0                                            Avatar   Color
# 1            1          Pirates of the Caribbean: At World's End   Color
# 2            2                                           Spectre   Color
# 3            3                             The Dark Knight Rises   Color
# 4            4  Star Wars: Episode VII - The Force Awakens    ...      0
# ..         ...                                                ...    ...
# 95          95                           Guardians of the Galaxy   Color
# 96          96                                      Interstellar   Color
# 97          97                                         Inception   Color
# 98          98                               Godzilla Resurgence   Color
# 99          99                 The Hobbit: An Unexpected Journey   Color
#
#         director_name  num_critic_for_reviews  duration  \
# ...

# %%
x = data["gross"]
y = data["director_facebook_likes"]

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.16667736],
#        [0.16667736, 1.        ]])

# %%
import seaborn as sns

sns.regplot(x=data["gross"], y=data["director_facebook_likes"])

# %% [markdown]
# ##3.Does the plot of the movie dependent to budget? Show the positive and negative correlation if there is?
# #### -The budget of a film is important throughout its life cycle, with effects that reach far beyond the film's cost. The amount that distributors will pay for a film is usually estimated as a percentage of the budget, independent of the script, cast, or anything else. The correlation of the budget is more applicable to the duration of the film.

# %%
budget = data["budget"]
dur= data["duration"]

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.16667736],
#        [0.16667736, 1.        ]])

# %%
import seaborn as sns

sns.regplot(x=data["budget"], y=data["duration"])
